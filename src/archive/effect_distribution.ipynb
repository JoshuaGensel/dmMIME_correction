# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 5
theta = .2
# plot gamma distribution
samples = np.random.lognormal(1, 1, 100000)
plt.hist(samples, 50, density=True)
#add mean line
plt.axvline(np.mean(samples), color='r', linestyle='dashed', linewidth=2)
plt.show()
print("mean: ", np.mean(samples))
# Out:
# mean:  4.47743971653058

# %%
log_samples = np.log(samples)

# plot lognormal distribution
plt.hist(log_samples, 50, density=True)
#add mean line
plt.axvline(np.mean(log_samples), color='r', linestyle='dashed', linewidth=2)
plt.show()

# %%
alpha = 4
beta = 2
# plot beta distribution
samples = np.exp((np.random.beta(alpha, beta, 1000000)-0)*3)
plt.hist(samples, 100, density=True)
#add mean line
plt.axvline(np.mean(samples), color='r', linestyle='dashed', linewidth=2)
# # x axis limit
# plt.xlim(0, 10)
plt.show()

# %%
log_samples = np.log(samples)
plt.hist(log_samples, 100, density=True)
#add mean line
plt.axvline(np.mean(log_samples), color='r', linestyle='dashed', linewidth=2)

# %%
# compute variance of log samples
print("mean: ", np.mean(log_samples))
print("variance: ", np.var(log_samples))
# Out:
# mean:  1.9997342260293327
# variance:  0.285576018225182

# %%
#normal distribution
mean = -.5
std = .3

samples = np.random.normal(mean, std, 1000000)
plt.hist(samples, 100, density=True)
#add mean line
plt.axvline(np.mean(samples), color='r', linestyle='dashed', linewidth=2)
plt.show()
