# %%
import numpy as np
import sympy as sp
sp.init_printing(use_latex=True)

# %%
x_1, x_2, x_3, y_1, y_2, y_3, p_1, p_2, p_3 = sp.symbols('x_1 x_2 x_3 y_1 y_2 y_3 p_1 p_2 p_3')

# %%
equation_x_1 = sp.Eq(sp.log(x_1), sp.log(y_1) + p_1 * sp.log(y_1/y_1) + p_1 * sp.log(x_1) + p_2 * sp.log(y_2/y_1) + p_2 * sp.log(x_1) + p_3 * sp.log(y_3/y_1) + p_3 * sp.log(x_1))
display(equation_x_1)
equation_x_2 = sp.Eq(sp.log(x_2), sp.log(y_2) + p_1 * sp.log(y_1/y_2) + p_1 * sp.log(x_2) + p_2 * sp.log(y_2/y_2) + p_2 * sp.log(x_2) + p_3 * sp.log(y_3/y_2) + p_3 * sp.log(x_2))
display(equation_x_2)
equation_x_3 = sp.Eq(sp.log(x_3), sp.log(y_3) + p_1 * sp.log(y_1/y_3) + p_1 * sp.log(x_3) + p_2 * sp.log(y_2/y_3) + p_2 * sp.log(x_3) + p_3 * sp.log(y_3/y_3) + p_3 * sp.log(x_3))
display(equation_x_3)
# Out:
#                                           ⎛y₂⎞                      ⎛y₃⎞
# log(x₁) = p₁⋅log(x₁) + p₂⋅log(x₁) + p₂⋅log⎜──⎟ + p₃⋅log(x₁) + p₃⋅log⎜──⎟ + log
#                                           ⎝y₁⎠                      ⎝y₁⎠
#
#
# (y₁)
#                              ⎛y₁⎞                                   ⎛y₃⎞
# log(x₂) = p₁⋅log(x₂) + p₁⋅log⎜──⎟ + p₂⋅log(x₂) + p₃⋅log(x₂) + p₃⋅log⎜──⎟ + log
#                              ⎝y₂⎠                                   ⎝y₂⎠
#
#
# (y₂)
#                              ⎛y₁⎞                      ⎛y₂⎞
# log(x₃) = p₁⋅log(x₃) + p₁⋅log⎜──⎟ + p₂⋅log(x₃) + p₂⋅log⎜──⎟ + p₃⋅log(x₃) + log
#                              ⎝y₃⎠                      ⎝y₃⎠
#
#
# (y₃)

# %%
display(sp.solve(equation_x_1, x_1))
display(sp.solve(equation_x_2, x_2))
display(sp.solve(equation_x_3, x_3))
# Out:
# ⎡         ⎛y₂⎞         ⎛y₃⎞          ⎤
# ⎢ - p₂⋅log⎜──⎟ - p₃⋅log⎜──⎟ - log(y₁)⎥
# ⎢         ⎝y₁⎠         ⎝y₁⎠          ⎥
# ⎢ ───────────────────────────────────⎥
# ⎢           p₁ + p₂ + p₃ - 1         ⎥
# ⎣ℯ                                   ⎦
# ⎡         ⎛y₁⎞         ⎛y₃⎞          ⎤
# ⎢ - p₁⋅log⎜──⎟ - p₃⋅log⎜──⎟ - log(y₂)⎥
# ⎢         ⎝y₂⎠         ⎝y₂⎠          ⎥
# ⎢ ───────────────────────────────────⎥
# ⎢           p₁ + p₂ + p₃ - 1         ⎥
# ⎣ℯ                                   ⎦
# ⎡         ⎛y₁⎞         ⎛y₂⎞          ⎤
# ⎢ - p₁⋅log⎜──⎟ - p₂⋅log⎜──⎟ - log(y₃)⎥
# ⎢         ⎝y₃⎠         ⎝y₃⎠          ⎥
# ⎢ ───────────────────────────────────⎥
# ⎢           p₁ + p₂ + p₃ - 1         ⎥
# ⎣ℯ                                   ⎦

# %% [markdown]
# consensus with wolfram alpha, just different form

# %%
example_equation_x_1 = sp.Eq(sp.log(x_1), sp.log(3) + .05 * sp.log(3/3) + .05 * sp.log(x_1) + .05 * sp.log(1/3) + .05 * sp.log(x_1) + .05 * sp.log(1/3) + .05 * sp.log(x_1))
display(example_equation_x_1)
# Out:
# log(x₁) = 0.15⋅log(x₁) - 0.109861228866811 + log(3)

# %%
sp.solve(sp.Eq(sp.log(x_1), sp.log(3) + .05 * sp.log(3/3) + .05 * sp.log(x_1) + .05 * sp.log(1/3) + .05 * sp.log(x_1) + .05 * sp.log(1/3) + .05 * sp.log(x_1)), x_1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sp.solve(sp.Eq(sp.log(x_1), sp.log(3) + .05 * sp.log(3/3) + .05 * sp.log(x_1) + .05 * sp.log(1/3) + .05 * sp.log(x_1) + .05 * sp.log(1/3) + .05 * sp.log(x_1)), x_1)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/solvers/solvers.py:1145, in solve(f, *symbols, **flags)
#    1143         solution = _solve_undetermined(f[0], symbols, flags)
#    1144     if not solution:
# -> 1145         solution = _solve(f[0], *symbols, **flags)
#    1146 else:
#    1147     linear, solution = _solve_system(f, symbols, **flags)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/solvers/solvers.py:1634, in _solve(f, *symbols, **flags)
#    1632     t = Dummy('t')
#    1633     inv = _vsolve(u - t, symbol, **flags)
# -> 1634     soln = {i.subs(t, s) for i in inv for s in soln}
#    1635 except NotImplementedError:
#    1636     # perhaps _tsolve can handle f_num
#    1637     soln = None
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/solvers/solvers.py:1634, in <setcomp>(.0)
#    1632     t = Dummy('t')
#    1633     inv = _vsolve(u - t, symbol, **flags)
# -> 1634     soln = {i.subs(t, s) for i in inv for s in soln}
#    1635 except NotImplementedError:
#    1636     # perhaps _tsolve can handle f_num
#    1637     soln = None
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/basic.py:1040, in Basic.subs(self, *args, **kwargs)
#    1038 rv = self
#    1039 for old, new in sequence:
# -> 1040     rv = rv._subs(old, new, **kwargs)
#    1041     if not isinstance(rv, Basic):
#    1042         break
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/basic.py:1131, in Basic._subs.<locals>.fallback(self, old, new)
#    1129         args[i] = arg
#    1130 if hit:
# -> 1131     rv = self.func(*args)
#    1132     hack2 = hints.get('hack2', False)
#    1133     if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/function.py:466, in Function.__new__(cls, *args, **options)
#     458     raise TypeError(temp % {
#     459         'name': cls,
#     460         'qual': 'exactly' if len(cls.nargs) == 1 else 'at least',
#     461         'args': min(cls.nargs),
#     462         'plural': 's'*(min(cls.nargs) != 1),
#     463         'given': n})
#     465 evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 466 result = super().__new__(cls, *args, **options)
#     467 if evaluate and isinstance(result, cls) and result.args:
#     468     _should_evalf = [cls._should_evalf(a) for a in result.args]
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/function.py:307, in Application.__new__(cls, *args, **options)
#     304     raise ValueError("Unknown options: %s" % options)
#     306 if evaluate:
# --> 307     evaluated = cls.eval(*args)
#     308     if evaluated is not None:
#     309         return evaluated
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/functions/elementary/exponential.py:343, in exp.eval(cls, arg)
#     341 coeffs, log_term = [coeff], None
#     342 for term in Mul.make_args(terms):
# --> 343     term_ = logcombine(term)
#     344     if isinstance(term_, log):
#     345         if log_term is None:
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/simplify/simplify.py:1114, in logcombine(expr, force)
#    1110             other.append(k*log1.pop(k))
#    1112     return Add(*other)
# -> 1114 return _bottom_up(expr, f)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/traversal.py:236, in bottom_up(rv, F, atoms, nonbasic)
#     234 if args is not None:
#     235     if args:
# --> 236         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     237         if args != rv.args:
#     238             rv = rv.func(*args)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/traversal.py:236, in <listcomp>(.0)
#     234 if args is not None:
#     235     if args:
# --> 236         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     237         if args != rv.args:
#     238             rv = rv.func(*args)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/traversal.py:239, in bottom_up(rv, F, atoms, nonbasic)
#     237     if args != rv.args:
#     238         rv = rv.func(*args)
# --> 239     rv = F(rv)
#     240 elif atoms:
#     241     rv = F(rv)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/simplify/simplify.py:1092, in logcombine.<locals>.f(rv)
#    1090 # logs that have the same coefficient can multiply
#    1091 for k in list(log1.keys()):
# -> 1092     log1[Mul(*k)] = log(logcombine(Mul(*[
#    1093         l.args[0]**Mul(*c) for c, l in log1.pop(k)]),
#    1094         force=force), evaluate=False)
#    1096 # logs that have oppositely signed coefficients can divide
#    1097 for k in ordered(list(log1.keys())):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/simplify/simplify.py:1093, in <listcomp>(.0)
#    1090 # logs that have the same coefficient can multiply
#    1091 for k in list(log1.keys()):
#    1092     log1[Mul(*k)] = log(logcombine(Mul(*[
# -> 1093         l.args[0]**Mul(*c) for c, l in log1.pop(k)]),
#    1094         force=force), evaluate=False)
#    1096 # logs that have oppositely signed coefficients can divide
#    1097 for k in ordered(list(log1.keys())):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/expr.py:232, in Expr.__pow__(self, other, mod)
#     230 def __pow__(self, other, mod=None) -> Expr:
#     231     if mod is None:
# --> 232         return self._pow(other)
#     233     try:
#     234         _self, other, mod = as_int(self), as_int(other), as_int(mod)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/decorators.py:106, in call_highest_priority.<locals>.priority_decorator.<locals>.binary_op_wrapper(self, other)
#     104         if f is not None:
#     105             return f(self)
# --> 106 return func(self, other)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/expr.py:228, in Expr._pow(self, other)
#     225 @sympify_return([('other', 'Expr')], NotImplemented)
#     226 @call_highest_priority('__rpow__')
#     227 def _pow(self, other):
# --> 228     return Pow(self, other)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/power.py:371, in Pow.__new__(cls, b, e, evaluate)
#     367         if s.is_Number and s and den == \
#     368                 log(-factor_terms(b, sign=False)) + s*S.ImaginaryUnit*S.Pi:
#     369             return S.Exp1**(c*num)
# --> 371 obj = b._eval_power(e)
#     372 if obj is not None:
#     373     return obj
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/sympy/core/numbers.py:2354, in Integer._eval_power(self, expt)
#    2351 x, xexact = integer_nthroot(abs(self.p), expt.q)
#    2352 if xexact:
#    2353     # if it's a perfect root we've finished
# -> 2354     result = Integer(x**abs(expt.p))
#    2355     if self.is_negative:
#    2356         result *= S.NegativeOne**expt
#
# KeyboardInterrupt:

# %% [markdown]
# doesn't finish. wolfram alpha gives x_1 = 3.20027

# %%
y_1 = 3
y_2 = 1
y_3 = 1
p_1 = .05
p_2 = .05
p_3 = .05

np.exp((-p_2*np.log(y_2/y_1)-p_3*np.log(y_3/y_1)-np.log(y_1))/(p_1 + p_2 + p_3-1))
# Out:
# 3.200274351398535

# %% [markdown]
# seems legit :)
